# %%
import os
import pickle
import pandas as pd
from collections import defaultdict
from pathlib import Path

from pyologger.utils.folder_manager import load_configuration
from pyologger.utils.folder_manager import select_and_load_deployment

def list_valid_deployments(dataset_folder):
    dataset_path = Path(dataset_folder)
    deployment_folders = [
        p for p in dataset_path.iterdir()
        if p.is_dir() and (p / 'outputs' / 'data.pkl').exists()
    ]
    return deployment_folders

# --- Config & Paths ---
config, data_dir, color_mapping_path, montage_path = load_configuration()
dataset_id = "mian-juv-nese_sleep_lml-ano_JKB"
# dataset_id = "oror-adult-orca_hr-sr-vid_sw_JKB-PP"
dataset_folder = os.path.join(data_dir, dataset_id)

# --- Discover valid deployments ---
deployment_paths = list_valid_deployments(dataset_folder)
print(f"Found {len(deployment_paths)} deployments in {dataset_id}")
# Out:
# Found 13 deployments in mian-juv-nese_sleep_lml-ano_JKB

# %%
config
# Out:
# {'paths': {'container_data': '/data',
#   'local_private_data': '/Volumes/WORK-SSD/Datasets/Unpublished',
#   'local_private_meta_analysis_data': '/Volumes/WORK-SSD/Datasets/Unpublished/00_Meta-Analysis',
#   'local_private_media': '/Volumes/WORK-SSD/Media-Datasets/Unpublished',
#   'local_public_data': '/Volumes/WORK-SSD/Datasets/Published',
#   'local_public_meta_analysis_data': '/Volumes/WORK-SSD/Datasets/Published/00_Meta-Analysis',
#   'local_public_media': '/Volumes/WORK-SSD/Media-Datasets/Published',
#   'local_repo_path': '/Users/jessiekb/Documents/GitHub/EcoViz_DiveDB/pyologger',
#   'delta_lake': {'local': '/Volumes/WORK-SSD/DeltaLake',
#    'nautilus': 's3://.../DeltaLake',
#    'container': 'pelican://.../DeltaLake'},
#   'file_storage': {'host': '/Users/jessiekb/Documents/GitHub/EcoViz_DiveDB/pyologger/data/files',
#    'container': '/data/files'},
#   'postgres': {'local_data_mount': '/Users/jessiekb/Documents/GitHub/EcoViz_DiveDB/pyologger/data/pg_data'}},
#  'edf_import': {'target_frequencies': {}},
#  'run_selection': {'processing': True,
#   'segmentation': False,
#   'make_map': False,
#   'make_phylogeny': False},
#  'datasets': {'cafa-adult_tdr-imu_BT': {'deployments': ['2021-08-03_cafa-001']},
#   'wild-whale-adult_hr-sr_JG-PP': {'deployments': ['2018-08-27_bamu-002']},
#   'mile-adult-sese_vdr_argentina_RD-KM': {'deployments': ['2012-11-02_mile-001',
#     '2012-11-02_mile-002',
#     '2012-11-01_mile-003',
#     '2013-11-10_mile-006',
#     '2013-11-09_mile-008',
#     '2015-11-05_mile-011',
#     '2015-11-05_mile-013',
#     '2015-11-06_mile-014']},
#   'oror-adult-orca_hr-sr-vid_sw_JKB-PP': {'deployments': ['2023-06-13_oror-002',
#     '2023-06-23_oror-002',
#     '2023-09-29_oror-002',
#     '2023-10-18_oror-001',
#     '2023-10-18_oror-002',
#     '2023-10-26_oror-001',
#     '2023-12-12_oror-001',
#     '2024-01-16_oror-002',
#     '2024-01-24_oror-001',
#     '2024-06-06_oror-002',
#     '2024-12-19_oror-001',
#     '2025-01-30_oror-001',
#     '2025-05-30_oror-001',
#     '2025-06-04_oror-001',
#     '2025-06-04_oror-002']},
#   'pale-adult-lion_vid-accel_africa_TW': {'deployments': ['2024-10-21_pale-001',
#     '2024-10-22_pale-002',
#     '2024-10-21_pale-003',
#     '2024-10-22_pale-004',
#     '2015-05-28_pale-005',
#     '2015-07-03_pale-006',
#     '2015-07-01_pale-007',
#     '2015-07-16_pale-008',
#     '2015-10-15_pale-009',
#     '2015-06-16_pale-010',
#     '2015-11-10_pale-011',
#     '2014-11-13_pale-012',
#     '2014-10-03_pale-013',
#     '2014-09-24_pale-015',
#     '2014-09-26_pale-016',
#     '2014-10-01_pale-019',
#     '2014-10-19_pale-020',
#     '2014-11-25_pale-014',
#     '2015-04-13_pale-017',
#     '2014-09-23_pale-018']},
#   'mian-juv-nese_sleep_lml-ano_JKB': {'deployments': ['2019-10-25_mian-001',
#     '2020-04-10_mian-002',
#     '2020-04-24_mian-003',
#     '2020-09-26_mian-004',
#     '2020-10-08_mian-005',
#     '2020-10-16_mian-006',
#     '2020-10-23_mian-007',
#     '2021-03-26_mian-008',
#     '2021-04-04_mian-009',
#     '2021-04-10_mian-010',
#     '2021-04-17_mian-011',
#     '2021-04-26_mian-012',
#     '2022-04-01_mian-013']},
#   'mian-adult-nese_tdr-sr_TA-AT-YN-DC': {'deployments': ['2011-02-21_mian-1001',
#     '2011-02-23_mian-1002',
#     '2011-02-23_mian-1003',
#     '2011-06-09_mian-1005',
#     '2011-06-11_mian-1004',
#     '2011-06-14_mian-1006',
#     '2011-06-22_mian-1002',
#     '2012-02-07_mian-1008',
#     '2012-02-04_mian-1009',
#     '2012-02-06_mian-1010',
#     '2012-02-09_mian-1011',
#     '2012-02-11_mian-1012',
#     '2012-06-04_mian-1013',
#     '2012-06-03_mian-1014',
#     '2012-05-30_mian-1016',
#     '2012-06-05_mian-1015']}},
#  'environmental_covariates': {'dataset_catalog': {'bathymetry': {'default_source': 'gebco_2025',
#     'suggestions': {'gebco_2025': {'kind': 'raster_static',
#       'provider': 'GEBCO',
#       'url': 'https://www.gebco.net/data-products-gridded-bathymetry-data/gebco2025-grid',
#       'notes': 'Global bathymetry/elevation grid; already used by current plotting code.'}}},
#    'bathymetry_ice': {'default_source': 'gebco_2025_surface_plus_subice',
#     'suggestions': {'gebco_2025_surface_plus_subice': {'kind': 'raster_static',
#       'provider': 'GEBCO',
#       'url': 'https://www.gebco.net/data-products-gridded-bathymetry-data/gebco2025-grid',
#       'notes': 'Use GEBCO surface grid plus sub-ice grid to derive ice presence/elevation.'}}},
#    'sst': {'default_source': 'noaa_oisst_v2_1',
#     'suggestions': {'noaa_oisst_v2_1': {'kind': 'raster_timevarying',
#       'provider': 'NOAA NCEI',
#       'url': 'https://www.ncei.noaa.gov/products/optimum-interpolation-sst',
#       'notes': 'Daily 0.25 degree global SST, September 1 1981 to present.'}}},
#    'land_cover': {'default_source': 'esa_worldcover_2021',
#     'suggestions': {'esa_worldcover_2021': {'kind': 'raster_static_categorical',
#       'provider': 'ESA WorldCover',
#       'url': 'https://esa-worldcover.org/en/data-access',
#       'notes': 'Global 10 m categorical land cover for 2021.'},
#      'esa_worldcover_2020': {'kind': 'raster_static_categorical',
#       'provider': 'ESA WorldCover',
#       'url': 'https://esa-worldcover.org/en/data-access',
#       'notes': 'Global 10 m categorical land cover for 2020.'}}},
#    'human_impact': {'default_source': 'wcs_human_impact_index',
#     'suggestions': {'wcs_human_impact_index': {'kind': 'raster_timevarying',
#       'provider': 'WCS',
#       'variable': 'Human impact index',
#       'spatial_resolution': '300m',
#       'temporal_resolution': 'Annual',
#       'year_range': [2001, 2020],
#       'notes': 'User-specified WCS Human Impact Index, annual 300 m layer from 2001–2020.'}}}}},
#  'cleanup_intermediate_step_nc': True,
#  'make_phylogeny_runs': {'sleep_paper_phylogeny': {'analysis_id': 'sleep_paper_phylogeny',
#    'ncbi_db': '/Volumes/WORK-SSD/Datasets/Published/NCBI-Phylogeny-Data/taxa.sqlite',
#    'species': ['Mirounga angustirostris',
#     'Mirounga leonina',
#     'Halichoerus grypus',
#     'Pagophilus groenlandicus',
#     'Odobenus rosmarus',
#     'Arctocephalus pusillus',
#     'Callorhinus ursinus',
#     'Otaria byronia',
#     'Enhydra lutris',
#     'Tursiops truncatus',
#     'Delphinapterus leucas',
#     'Inia geoffrensis',
#     'Hippopotamus amphibius',
#     'Connochaetes taurinus',
#     'Oryx leucoryx',
#     'Moschus moschiferus',
#     'Tragulus kanchil',
#     'Rousettus aegyptiacus',
#     'Eonycteris spelaea',
#     'Cynopterus sphinx',
#     'Pteropus poliocephalus',
#     'Syconycteris australis',
#     'Myotis lucifugus',
#     'Myotis myotis',
#     'Macaca arctoides',
#     'Cheirogaleus medius',
#     'Cheirogaleus crossleyi',
#     'Cheirogaleus sibreei',
#     'Microcebus murinus',
#     'Marmota broweri',
#     'Urocitellus parryii',
#     'Callospermophilus lateralis',
#     'Trichechus inunguis'],
#    'layout': {'style': 'rectangular',
#     'figsize': [18, 10],
#     'branch_lengths': False},
#    'annotations': {'phylopic': True,
#     'silhouette_size': 0.025,
#     'silhouette_alpha': 0.85,
#     'color_by': None,
#     'metadata_csv': None},
#    'output_dir': '/Volumes/WORK-SSD/Datasets/Published/NCBI-Phylogeny-Data/sleep_paper_phylogeny/',
#    'outputs': {'png': True, 'svg': True, 'newick': True}}},
#  'make_map_runs': {'mian_algorithmic_rest_daily_maps': {'analysis_id': 'mian_algorithmic_rest_daily_maps',
#    'segmentation_analysis_id': 'mian_mile_sleep_transfer_rf',
#    'dataset_ids': ['mian-juv-nese_sleep_lml-ano_JKB'],
#    'deployment_ids': ['2021-04-04_mian-009',
#     '2021-04-17_mian-011',
#     '2022-04-01_mian-013'],
#    'location_downsample': {'enabled': True, 'target_interval': '1H'},
#    'maps': [{'map_id': 'mian_algorithmic_rest_daily_h_bathy_ice',
#      'color_mode': 'continuous',
#      'derived_metric': 'algorithmic_rest_daily_hours',
#      'value_channel': 'algorithmic_rest_h_per_day',
#      'time_bin': '1D',
#      'color_scale': 'magma',
#      'point_size_by': 'map_value',
#      'point_size_range': [1.5, 8.5],
#      'point_alpha': 0.9,
#      'rest_labels': ['find_rest.surface_sleep',
#       'find_rest.long_flat',
#       'find_rest.long_drift'],
#      'environmental_covariates': [{'type': 'bathymetry_ice'}]}]},
#   'eseal_sleep_maps': {'analysis_id': 'eseal_sleep_maps',
#    'dataset_ids': ['mian-juv-nese_sleep_lml-ano_JKB',
#     'mian-adult-nese_tdr-sr_TA-AT-YN-DC',
#     'mile-adult-sese_vdr_argentina_RD-KM'],
#    'deployment_ids': ['2021-04-04_mian-009',
#     '2021-04-17_mian-011',
#     '2022-04-01_mian-013',
#     '2012-11-02_mile-001',
#     '2012-11-02_mile-002',
#     '2012-11-01_mile-003',
#     '2013-11-10_mile-006',
#     '2013-11-09_mile-008',
#     '2015-11-05_mile-011',
#     '2015-11-05_mile-013',
#     '2015-11-06_mile-014',
#     '2011-02-21_mian-1001',
#     '2011-02-23_mian-1002',
#     '2011-02-23_mian-1003',
#     '2011-06-09_mian-1005',
#     '2011-06-11_mian-1004',
#     '2011-06-14_mian-1006',
#     '2011-06-22_mian-1002',
#     '2012-02-07_mian-1008',
#     '2012-02-04_mian-1009',
#     '2012-02-06_mian-1010',
#     '2012-02-09_mian-1011',
#     '2012-02-11_mian-1012',
#     '2012-06-04_mian-1013',
#     '2012-06-03_mian-1014',
#     '2012-05-30_mian-1016',
#     '2012-06-05_mian-1015'],
#    'location_downsample': {'enabled': True, 'target_interval': '1H'},
#    'maps': [{'map_id': 'mian_sleep_tracks_bathymetry_ice',
#      'color_mode': 'discrete',
#      'global_extent': False,
#      'environmental_covariates': [{'type': 'bathymetry_ice'}]},
#     {'map_id': 'mian_sleep_stroke_rate_hourly',
#      'color_mode': 'continuous',
#      'value_channel': 'stroke_rate.stroke_rate',
#      'time_bin': '1H',
#      'agg': 'mean',
#      'environmental_covariates': [{'type': 'bathymetry'}]}]}},
#  'processing_event_definitions': {'base': {'load_data': {'defaults': {'type': 'point'},
#     'event_keys': {'logger_status': {'short_description': 'logger_status',
#       'long_description': 'Logger status event generated during load-data workflow'}}},
#    'calibrate_pressure': {'defaults': {'type': 'state'},
#     'event_keys': {'dive': {'short_description': 'dive_start',
#       'long_description': 'Dive state generated during pressure calibration'},
#      'dive-with-nan': {'short_description': 'dive-with-nan_start',
#       'long_description': 'Dive state contains NaNs and is flagged during pressure calibration'}}},
#    'heartbeat_detect': {'defaults': {'type': 'state'},
#     'event_keys': {'heartbeat_auto_detect_accepted': {'short_description': 'heartbeat_auto_detect_accepted_start',
#       'long_description': 'Auto heartbeat interval accepted by heartbeat workflow'},
#      'heartbeat_auto_detect_rejected': {'short_description': 'heartbeat_auto_detect_rejected_start',
#       'long_description': 'Auto heartbeat interval rejected by heartbeat workflow'}}}}},
#  'segmentation_runs': {'finescale_hr': {'scope': {'analysis_id': 'finescale_hr',
#     'dataset_ids': ['oror-adult-orca_hr-sr-vid_sw_JKB-PP',
#      'mian-juv-nese_sleep_lml-ano_JKB'],
#     'deployment_ids': ['2023-06-13_oror-002',
#      '2023-06-23_oror-002',
#      '2023-09-29_oror-002',
#      '2023-10-18_oror-001',
#      '2023-10-18_oror-002',
#      '2023-12-12_oror-001',
#      '2024-01-16_oror-002',
#      '2024-01-24_oror-001',
#      '2024-06-06_oror-002',
#      '2024-12-19_oror-001',
#      '2025-01-30_oror-001',
#      '2021-04-04_mian-009',
#      '2021-04-17_mian-011',
#      '2022-04-01_mian-013'],
#     'expected_signals': ['depth', 'heart_rate', 'stroke_rate'],
#     'groups': {'KW': ['2023-06-13_oror-002',
#       '2023-06-23_oror-002',
#       '2023-09-29_oror-002',
#       '2023-10-18_oror-001',
#       '2023-10-18_oror-002',
#       '2023-12-12_oror-001',
#       '2024-01-16_oror-002',
#       '2024-01-24_oror-001',
#       '2024-06-06_oror-002',
#       '2024-12-19_oror-001',
#       '2025-01-30_oror-001'],
#      'NES': ['2021-04-04_mian-009',
#       '2021-04-17_mian-011',
#       '2022-04-01_mian-013']}},
#    'features': {'normalization_level': 'deployment',
#     'cluster_length_mode': 'fixed',
#     'duration_s': 10,
#     'min_samples_per_chunk': 5,
#     'max_chunks_per_deployment': 40000,
#     'max_chunks_total': 1000000,
#     'test_run': False,
#     'test_max_chunks_per_deployment': 1000,
#     'umap_sample_frac': 0.2,
#     'random_state': 42,
#     'strict_qc': False,
#     'sampling_compatibility_tolerance': None,
#     'channel_feature_spec': {'heart_rate.heart_rate': {'transforms': ['raw'],
#       'feature_set': 'full'},
#      'stroke_rate.stroke_rate': {'transforms': ['raw'], 'feature_set': 'full'},
#      'depth.depth': {'transforms': ['raw'],
#       'feature_set': 'medium',
#       'required': False}}},
#    'unsupervised': {'cluster_passes': [{'name': 'k3',
#       'n_clusters': 3,
#       'channel_feature_spec': {'heart_rate.heart_rate': {'transforms': ['raw'],
#         'feature_set': 'full'},
#        'stroke_rate.stroke_rate': {'transforms': ['raw'],
#         'feature_set': 'full'}}},
#      {'name': 'k5',
#       'n_clusters': 5,
#       'channel_feature_spec': {'heart_rate.heart_rate': {'transforms': ['raw'],
#         'feature_set': 'full'},
#        'stroke_rate.stroke_rate': {'transforms': ['raw'],
#         'feature_set': 'full'},
#        'depth.depth': {'transforms': ['raw'],
#         'feature_set': 'medium',
#         'required': False}}}],
#     'primary_input_channel_for_ranking': 'heart_rate.heart_rate',
#     'corr_threshold': 0.8,
#     'n_clusters': 'auto',
#     'max_k': 8,
#     'run_pca': True,
#     'run_tsne': False,
#     'run_umap': True},
#    'supervised': {'enabled': False,
#     'config': {'test_size': 0.4,
#      'rf_n_estimators': 500,
#      'rf_min_samples_leaf': 2,
#      'rf_class_weight': 'balanced_subsample',
#      'confidence_threshold': 0.4}},
#    'summary': {'config': {'primary_method_kind': 'clustering',
#      'primary_method_id': 'clustered_windows',
#      'budget_label_mode': 'canonical',
#      'actograms': {'daily': False, 'continuous': False}}}},
#   'lions_cluster_test': {'scope': {'analysis_id': 'lions_cluster_test',
#     'dataset_ids': ['pale-adult-lion_vid-accel_africa_TW'],
#     'deployment_ids': ['2024-10-21_pale-001',
#      '2024-10-22_pale-002',
#      '2024-10-21_pale-003',
#      '2024-10-22_pale-004',
#      '2015-05-28_pale-005',
#      '2015-07-03_pale-006',
#      '2015-07-01_pale-007',
#      '2015-07-16_pale-008',
#      '2015-10-15_pale-009',
#      '2015-06-16_pale-010',
#      '2015-11-10_pale-011',
#      '2014-11-13_pale-012',
#      '2014-10-03_pale-013',
#      '2014-09-24_pale-015',
#      '2014-09-26_pale-016',
#      '2014-10-01_pale-019',
#      '2014-10-19_pale-020',
#      '2014-11-25_pale-014',
#      '2015-04-13_pale-017'],
#     'expected_signals': ['accelerometer',
#      'odba',
#      'prh',
#      'location',
#      'dynamic_accel',
#      'stroke_rate',
#      'label'],
#     'groups': {'Kruger_M': ['2024-10-21_pale-001', '2024-10-22_pale-002'],
#      'Kruger_F': ['2024-10-21_pale-003', '2024-10-22_pale-004'],
#      'Kenya_M': ['2015-05-28_pale-005',
#       '2015-07-03_pale-006',
#       '2015-07-01_pale-007',
#       '2015-07-16_pale-008',
#       '2015-10-15_pale-009',
#       '2015-06-16_pale-010',
#       '2015-11-10_pale-011'],
#      'Kenya_F': ['2014-11-13_pale-012',
#       '2014-10-03_pale-013',
#       '2014-09-24_pale-015',
#       '2014-09-26_pale-016',
#       '2014-10-01_pale-019',
#       '2014-10-19_pale-020',
#       '2014-11-25_pale-014',
#       '2015-04-13_pale-017']}},
#    'features': {'normalization_level': 'deployment',
#     'cluster_length_mode': 'fixed',
#     'duration_s': 30,
#     'min_samples_per_chunk': 10,
#     'max_chunks_per_deployment': 40000,
#     'max_chunks_total': 1000000,
#     'test_run': False,
#     'test_max_chunks_per_deployment': 1000,
#     'umap_sample_frac': 0.1,
#     'random_state': 42,
#     'strict_qc': False,
#     'channel_feature_spec': {'odba.odba': {'transforms': ['raw'],
#       'feature_set': 'full'},
#      'prh.pitch': {'transforms': ['raw'], 'feature_set': 'medium'},
#      'prh.roll': {'transforms': ['raw'], 'feature_set': 'medium'},
#      'dynamic_accel.dynX': {'transforms': ['raw'],
#       'feature_set': 'full',
#       'required': False},
#      'dynamic_accel.dynY': {'transforms': ['raw'],
#       'feature_set': 'full',
#       'required': False},
#      'stroke_rate.stroke_rate': {'transforms': ['raw'],
#       'feature_set': 'medium',
#       'required': False}},
#     'include_corrected_acc': False,
#     'keep_unified_df': False,
#     'memory_log_interval_s': 30,
#     'enable_catch22': True,
#     'catch22_feature_cols': [],
#     'catch22_max_chunks_per_deployment': None},
#    'unsupervised': {'cluster_passes': [{'name': 'k2',
#       'n_clusters': 2,
#       'channel_feature_spec': {'odba.odba': {'transforms': ['raw'],
#         'feature_set': 'full'}}},
#      {'name': 'k5',
#       'n_clusters': 5,
#       'channel_feature_spec': {'odba.odba': {'transforms': ['raw'],
#         'feature_set': 'full'},
#        'prh.pitch': {'transforms': ['raw'], 'feature_set': 'medium'},
#        'prh.roll': {'transforms': ['raw'], 'feature_set': 'medium'},
#        'dynamic_accel.dynX': {'transforms': ['raw'],
#         'feature_set': 'full',
#         'required': False},
#        'dynamic_accel.dynY': {'transforms': ['raw'],
#         'feature_set': 'full',
#         'required': False},
#        'stroke_rate.stroke_rate': {'transforms': ['raw'],
#         'feature_set': 'medium',
#         'required': False}}}],
#     'primary_input_channel_for_ranking': 'odba.odba',
#     'corr_threshold': 0.8,
#     'n_clusters': 5,
#     'max_k': 8,
#     'run_pca': True,
#     'run_tsne': False,
#     'run_umap': False},
#    'supervised': {'enabled': True,
#     'config': {'test_size': 0.4,
#      'rf_n_estimators': 500,
#      'rf_min_samples_leaf': 2,
#      'rf_class_weight': 'balanced_subsample',
#      'enable_lightgbm': False,
#      'lightgbm_n_estimators': 300,
#      'lightgbm_learning_rate': 0.05,
#      'lightgbm_num_leaves': 31,
#      'enable_svm': False,
#      'svm_kernel': 'rbf',
#      'svm_c': 1.0,
#      'svm_gamma': 'scale',
#      'enable_knn': False,
#      'knn_n_neighbors': 25,
#      'knn_weights': 'distance',
#      'enable_channel_ablation': True,
#      'ablation_mode': 'grouped_forward_addition',
#      'ablation_feature_groups': [{'label': 'ODBA Only',
#        'channels': ['odba.odba']},
#       {'label': 'ODBA + PRH',
#        'channels': ['odba.odba', 'prh.pitch', 'prh.roll']},
#       {'label': 'ODBA + PRH + Dyn Accel',
#        'channels': ['odba.odba',
#         'prh.pitch',
#         'prh.roll',
#         'dynamic_accel.dynX',
#         'dynamic_accel.dynY']},
#       {'label': 'ODBA + PRH + Dyn Accel + Stroke',
#        'channels': ['odba.odba',
#         'prh.pitch',
#         'prh.roll',
#         'dynamic_accel.dynX',
#         'dynamic_accel.dynY',
#         'stroke_rate.stroke_rate']}],
#      'include_algorithmic_baseline': False,
#      'prediction_scope': 'all_windows',
#      'confidence_threshold': 0.4,
#      'use_probability_calibration': True,
#      'calibration_method': 'sigmoid',
#      'calibration_cv': 3,
#      'export_rf_events': True,
#      'label_group': 'BEHAVIOR_LIONS'}},
#    'summary': {'config': {'primary_method_kind': 'algorithmic',
#      'primary_method_id': 'algorithmic_segments',
#      'budget_label_mode': 'canonical',
#      'actograms': {'daily': True, 'continuous': True}}}},
#   'mian_sleep_rf_test': {'scope': {'analysis_id': 'mian_sleep_rf_test',
#     'dataset_ids': ['mian-juv-nese_sleep_lml-ano_JKB'],
#     'deployment_ids': ['2021-04-04_mian-009',
#      '2021-04-17_mian-011',
#      '2022-04-01_mian-013'],
#     'expected_signals': ['depth', 'prh', 'velocity', 'stroke_rate', 'label'],
#     'groups': {'mian_sleep': ['2021-04-04_mian-009',
#       '2021-04-17_mian-011',
#       '2022-04-01_mian-013']}},
#    'algorithmic': {'segments': {'enabled': True,
#      'method': 'depth_drift_thresholds',
#      'method_name': 'rest',
#      'source_channel': 'depth.depth',
#      'standardize': True,
#      'quantize_step': 1.0,
#      'base_smooth_seconds': 6,
#      'coarse_smooth_seconds': 12,
#      'coarse_interval_threshold_s': 5,
#      'coarse_resolution_threshold': 1.0,
#      'end_segments_upon_d1_sign_change': True,
#      'filter_out_ascent': True,
#      'filter_out_descent': False,
#      'thresholds': {'drift_rate_abs_max_ms': 0.55,
#       'curvature_abs_max_ms': 0.3},
#      'terminal_criteria': {'unscorable': {'enabled': True,
#        'uses_min_duration': True,
#        'uses_nonzero_mean_d1': True,
#        'uses_zero_mean_d2': True}},
#      'label_group': 'WAKE_v_SLEEP_SEALS',
#      'event_keys': {'initial': 'rest.initial', 'filtered': 'rest.filtered'},
#      'context_filters': [{'use': 'low_stroke_rate_required',
#        'rule': {'keep_if': {'comparator': '<', 'threshold': 10.0}}}],
#      'unscorable_interpolated_gap_min_duration_s': 40.0,
#      'unscorable_interpolated_gap_min_abs_mean_d1_ms': 0.0,
#      'unscorable_interpolated_gap_max_abs_mean_d2_ms2': 0.0,
#      'unscorable_interpolated_gap_abs_mean_d2_tolerance_ms2': 1e-09,
#      'expected_signals': ['depth', 'prh', 'velocity', 'stroke_rate', 'label'],
#      'channel_feature_spec': {'depth.depth': {'transforms': ['raw',
#         'diff',
#         'diff2'],
#        'feature_set': 'full'},
#       'prh.pitch': {'transforms': ['raw'], 'feature_set': 'full'},
#       'prh.roll': {'transforms': ['raw'], 'feature_set': 'full'},
#       'prh.heading': {'transforms': ['raw'],
#        'feature_set': 'full',
#        'required': False},
#       'velocity.velocity': {'transforms': ['raw'],
#        'feature_set': 'full',
#        'required': False},
#       'stroke_rate.stroke_rate': {'transforms': ['raw'],
#        'feature_set': 'medium',
#        'required': False}},
#      'primary_input_channel_for_ranking': 'depth.depth',
#      'corr_threshold': 0.8,
#      'n_clusters': 5,
#      'max_k': 8,
#      'run_pca': True,
#      'run_tsne': False,
#      'run_umap': True}},
#    'features': {'normalization_level': 'deployment',
#     'cluster_length_mode': 'fixed',
#     'duration_s': 30,
#     'min_samples_per_chunk': 10,
#     'max_chunks_per_deployment': 40000,
#     'max_chunks_total': 1000000,
#     'test_run': False,
#     'test_max_chunks_per_deployment': 1000,
#     'umap_sample_frac': 0.1,
#     'random_state': 42,
#     'strict_qc': False,
#     'sampling_compatibility_tolerance': 0.05,
#     'channel_feature_spec': {'depth.depth': {'transforms': ['raw',
#        'diff',
#        'diff2'],
#       'feature_set': 'full'},
#      'prh.pitch': {'transforms': ['raw'], 'feature_set': 'full'},
#      'prh.roll': {'transforms': ['raw'], 'feature_set': 'full'},
#      'prh.heading': {'transforms': ['raw'],
#       'feature_set': 'full',
#       'required': False},
#      'velocity.velocity': {'transforms': ['raw'],
#       'feature_set': 'full',
#       'required': False},
#      'stroke_rate.stroke_rate': {'transforms': ['raw'],
#       'feature_set': 'medium',
#       'required': False}}},
#    'unsupervised': {'primary_input_channel_for_ranking': 'depth.depth',
#     'corr_threshold': 0.8,
#     'n_clusters': 5,
#     'max_k': 8,
#     'run_pca': True,
#     'run_tsne': False,
#     'run_umap': True},
#    'supervised': {'enabled': True,
#     'config': {'test_size': 0.4,
#      'rf_n_estimators': 500,
#      'rf_min_samples_leaf': 2,
#      'rf_class_weight': 'balanced_subsample',
#      'enable_lightgbm': False,
#      'lightgbm_n_estimators': 300,
#      'lightgbm_learning_rate': 0.05,
#      'lightgbm_num_leaves': 31,
#      'enable_svm': False,
#      'svm_kernel': 'rbf',
#      'svm_c': 1.0,
#      'svm_gamma': 'scale',
#      'enable_knn': False,
#      'knn_n_neighbors': 25,
#      'knn_weights': 'distance',
#      'enable_channel_ablation': True,
#      'ablation_mode': 'grouped_forward_addition',
#      'ablation_feature_groups': [{'label': 'Depth Only',
#        'channels': ['depth.depth']},
#       {'label': 'Depth + Accel',
#        'channels': ['depth.depth',
#         'stroke_rate.stroke_rate',
#         'prh.pitch',
#         'prh.roll']},
#       {'label': 'Depth + Accel + Mag',
#        'channels': ['depth.depth',
#         'stroke_rate.stroke_rate',
#         'prh.pitch',
#         'prh.roll',
#         'prh.heading']},
#       {'label': 'Depth + Accel + Mag + Speed',
#        'channels': ['depth.depth',
#         'stroke_rate.stroke_rate',
#         'prh.pitch',
#         'prh.roll',
#         'prh.heading',
#         'velocity.velocity']}],
#      'include_algorithmic_baseline': True,
#      'confidence_threshold': 0.4,
#      'use_probability_calibration': True,
#      'calibration_method': 'sigmoid',
#      'calibration_cv': 3,
#      'export_rf_events': True,
#      'context_filters': ['inferred_buoyancy_must-be-aligned',
#       'gliding_must-be-true'],
#      'label_group': 'WAKE_v_REST_SEALS'}},
#    'summary': {'config': {'primary_method_kind': 'algorithmic',
#      'primary_method_id': 'algorithmic_segments',
#      'budget_label_mode': 'canonical',
#      'actograms': {'daily': True, 'continuous': True}}}},
#   'mian_mile_depth_standardized_30s': {'scope': {'analysis_id': 'mian_mile_depth_standardized_30s',
#     'dataset_ids': ['mile-adult-sese_vdr_argentina_RD-KM',
#      'mian-adult-nese_tdr-sr_TA-AT-YN-DC',
#      'mian-juv-nese_sleep_lml-ano_JKB'],
#     'deployment_ids': ['2021-04-04_mian-009',
#      '2021-04-17_mian-011',
#      '2022-04-01_mian-013',
#      '2012-11-02_mile-001',
#      '2012-11-02_mile-002',
#      '2012-11-01_mile-003',
#      '2013-11-10_mile-006',
#      '2013-11-09_mile-008',
#      '2015-11-05_mile-011',
#      '2015-11-05_mile-013',
#      '2015-11-06_mile-014',
#      '2011-02-21_mian-1001',
#      '2011-02-23_mian-1002',
#      '2011-02-23_mian-1003',
#      '2011-06-09_mian-1005',
#      '2011-06-11_mian-1004',
#      '2011-06-14_mian-1006',
#      '2011-06-22_mian-1002',
#      '2012-02-07_mian-1008',
#      '2012-02-04_mian-1009',
#      '2012-02-06_mian-1010',
#      '2012-02-09_mian-1011',
#      '2012-02-11_mian-1012',
#      '2012-06-04_mian-1013',
#      '2012-06-03_mian-1014',
#      '2012-05-30_mian-1016',
#      '2012-06-05_mian-1015'],
#     'expected_signals': ['depth', 'stroke_rate']},
#    'algorithmic': {'segments': {'enabled': True,
#      'method': 'depth_drift_thresholds',
#      'method_name': 'find_rest',
#      'source_channel': 'depth.depth',
#      'standardize': True,
#      'quantize_step': 1.0,
#      'base_smooth_seconds': 6,
#      'coarse_smooth_seconds': 12,
#      'coarse_interval_threshold_s': 5,
#      'coarse_resolution_threshold': 1.0,
#      'end_segments_upon_d1_sign_change': True,
#      'filter_out_ascent': False,
#      'filter_out_descent': False,
#      'thresholds': {'dive_depth_min_m': 2.0,
#       'first_deriv_abs_max_ms': 0.6,
#       'second_deriv_abs_max_ms2': 0.05,
#       'min_duration_s': 180.0,
#       'surface_sleep_min_duration_s': 600.0,
#       'drift_rate_abs_max_ms': 0.3,
#       'curvature_abs_max_ms': 0.1,
#       'end_flat_abs_mean_d1_max_ms': 0.01,
#       'unscorable_interpolated_gap_min_duration_s': 40.0,
#       'unscorable_interpolated_gap_min_abs_mean_d1_ms': 0.0,
#       'unscorable_interpolated_gap_max_abs_mean_d2_ms2': 0.0,
#       'unscorable_interpolated_gap_abs_mean_d2_tolerance_ms2': 1e-09},
#      'terminal_criteria': {'unscorable': {'enabled': True,
#        'uses_min_duration': True,
#        'uses_nonzero_mean_d1': True,
#        'uses_zero_mean_d2': True}},
#      'label_group': 'WAKE_v_SLEEP_SEALS',
#      'event_keys': {'initial': 'find_rest.initial',
#       'filtered': 'find_rest.filtered'},
#      'debug': {'write_context_review_table': True,
#       'persist_context_helper_channels': False,
#       'persist_intermediate_channels': True},
#      'covariates': {'intrinsic': {'inferred_buoyancy': {'enabled': True,
#         'provider': 'smoothed_segment_metric',
#         'source_metric': 'drift_rate_ms',
#         'subset_filters': {'min_duration_s': 180.0,
#          'max_start_depth_m': 500.0,
#          'exclude_long_flats': True},
#         'smoothing': {'method': 'rolling_fraction',
#          'window_fraction_of_trip': 0.05,
#          'min_periods': 1},
#         'phase_thresholds': {'negative_max': -0.03, 'positive_min': 0.0},
#         'trip_phase_inference': {'min_positive_elapsed_days': 20.0,
#          'backtrack_days': 20.0,
#          'always_positive_max_day': 20.0,
#          'near_arrival_exclusion_days': 5.0,
#          'early_window_days': 15.0,
#          'late_window_days': 15.0,
#          'reference_max_start_depth_m': 500.0},
#         'outputs': {'segment_value_field': 'inferred_buoyancy_value',
#          'segment_phase_field': 'inferred_buoyancy_phase',
#          'segment_positive_likely_day_field': 'inferred_positive_likely_day',
#          'segment_trip_phase_field': 'inferred_trip_phase',
#          'segment_early_reference_field': 'inferred_buoyancy_early_reference_value',
#          'segment_late_reference_field': 'inferred_buoyancy_late_reference_value'}},
#        'stroke_rate_rest_gate': {'enabled': True,
#         'provider': 'segment_channel_stat',
#         'source_channel': 'stroke_rate.stroke_rate',
#         'agg': 'mean',
#         'outputs': {'segment_value_field': 'segment_mean_stroke_rate_spm',
#          'segment_phase_field': 'segment_stroke_rate_phase',
#          'segment_trip_phase_field': 'segment_stroke_rate_trip_phase'}}},
#       'extrinsic': {}},
#      'context_filters': ['low_stroke_rate_required',
#       'drift_within_intrinsic_context',
#       'prepositive_negative_only',
#       'prepositive_negative_long_enough',
#       'prepositive_negative_not_benthic_transit',
#       'postpositive_negative_deep_enough',
#       'postpositive_negative_long_enough',
#       'early_trip_refinement',
#       'late_trip_refinement']}},
#    'features': {'normalization_level': 'deployment',
#     'cluster_length_mode': 'variable',
#     'window_s': 30,
#     'stride_s': 10,
#     'min_samples_per_chunk': 5,
#     'max_chunks_per_deployment': 40000,
#     'max_chunks_total': 1000000,
#     'test_run': False,
#     'test_max_chunks_per_deployment': 1000,
#     'umap_sample_frac': 0.1,
#     'random_state': 42,
#     'strict_qc': False,
#     'sampling_compatibility_tolerance': 0.05,
#     'channel_feature_spec': {'standardized_depth.depth_std': {'transforms': ['raw'],
#       'feature_set': 'full'},
#      'standardized_depth.depth_d1_std': {'transforms': ['raw'],
#       'feature_set': 'full'},
#      'standardized_depth.depth_d2_std': {'transforms': ['raw'],
#       'feature_set': 'full'}},
#     'preprocessing': {'standardized_channels': {'depth.depth': {'method': 'adaptive_gaussian_quantized',
#        'quantize_step': 1.0,
#        'base_smooth_seconds': 6,
#        'coarse_smooth_seconds': 12,
#        'coarse_interval_threshold_s': 5,
#        'coarse_resolution_threshold': 1.0,
#        'derivative_orders': [0, 1, 2],
#        'output_prefix': 'standardized_depth'}}}},
#    'unsupervised': {'cluster_passes': [{'name': 'k2',
#       'n_clusters': 2,
#       'channel_feature_spec': {'standardized_depth.depth_std': {'transforms': ['raw'],
#         'feature_set': 'full'}}},
#      {'name': 'k5',
#       'n_clusters': 5,
#       'channel_feature_spec': {'standardized_depth.depth_d1_std': {'transforms': ['raw'],
#         'feature_set': 'full'},
#        'standardized_depth.depth_d2_std': {'transforms': ['raw'],
#         'feature_set': 'full'}}}],
#     'primary_input_channel_for_ranking': 'standardized_depth.depth_std',
#     'corr_threshold': 0.8,
#     'n_clusters': 'auto',
#     'max_k': 8,
#     'run_pca': True,
#     'run_tsne': False,
#     'run_umap': False},
#    'supervised': {'enabled': False,
#     'config': {'test_size': 0.4,
#      'rf_n_estimators': 500,
#      'rf_min_samples_leaf': 2,
#      'rf_class_weight': 'balanced_subsample',
#      'confidence_threshold': 0.4}}},
#   'mian_mile_sleep_transfer_rf': {'scope': {'analysis_id': 'mian_mile_sleep_transfer_rf',
#     'dataset_ids': ['mile-adult-sese_vdr_argentina_RD-KM',
#      'mian-adult-nese_tdr-sr_TA-AT-YN-DC',
#      'mian-juv-nese_sleep_lml-ano_JKB'],
#     'deployment_ids': ['2021-04-04_mian-009',
#      '2021-04-17_mian-011',
#      '2022-04-01_mian-013',
#      '2012-11-02_mile-002',
#      '2012-11-01_mile-003',
#      '2013-11-10_mile-006',
#      '2013-11-09_mile-008',
#      '2012-11-02_mile-001',
#      '2015-11-05_mile-011',
#      '2015-11-05_mile-013',
#      '2015-11-06_mile-014',
#      '2011-02-21_mian-1001',
#      '2011-02-23_mian-1003',
#      '2011-06-09_mian-1005',
#      '2011-06-11_mian-1004',
#      '2011-06-14_mian-1006',
#      '2011-06-22_mian-1002',
#      '2012-02-07_mian-1008',
#      '2012-02-04_mian-1009',
#      '2012-02-06_mian-1010',
#      '2012-02-09_mian-1011',
#      '2012-02-11_mian-1012',
#      '2012-06-04_mian-1013',
#      '2012-06-03_mian-1014',
#      '2012-05-30_mian-1016',
#      '2012-06-05_mian-1015'],
#     'expected_signals': ['depth', 'prh', 'velocity', 'stroke_rate']},
#    'algorithmic': {'segments': {'enabled': True,
#      'method': 'depth_drift_thresholds',
#      'method_name': 'rest',
#      'source_channel': 'depth.depth',
#      'standardize': True,
#      'quantize_step': 1.0,
#      'base_smooth_seconds': 6,
#      'coarse_smooth_seconds': 12,
#      'coarse_interval_threshold_s': 5,
#      'coarse_resolution_threshold': 1.0,
#      'end_segments_upon_d1_sign_change': True,
#      'filter_out_ascent': True,
#      'filter_out_descent': False,
#      'thresholds': {'drift_rate_abs_max_ms': 0.55,
#       'curvature_abs_max_ms': 0.3},
#      'terminal_criteria': {'unscorable': {'enabled': True,
#        'uses_min_duration': True,
#        'uses_nonzero_mean_d1': True,
#        'uses_zero_mean_d2': True,
#        'uses_surface_light_missing': True,
#        'surface_light_missing_min_fraction': 0.1,
#        'surface_light_missing_dataset_ids': ['mile-adult-sese_vdr_argentina_RD-KM']}},
#      'label_group': 'WAKE_v_SLEEP_SEALS',
#      'event_keys': {'initial': 'rest.initial', 'filtered': 'rest.filtered'},
#      'context_filters': [{'use': 'low_stroke_rate_required',
#        'rule': {'keep_if': {'comparator': '<', 'threshold': 10.0}}}],
#      'unscorable_interpolated_gap_min_duration_s': 40.0,
#      'unscorable_interpolated_gap_min_abs_mean_d1_ms': 0.0,
#      'unscorable_interpolated_gap_max_abs_mean_d2_ms2': 0.0,
#      'unscorable_interpolated_gap_abs_mean_d2_tolerance_ms2': 1e-09,
#      'expected_signals': ['depth', 'prh', 'velocity', 'stroke_rate', 'label'],
#      'channel_feature_spec': {'depth.depth': {'transforms': ['raw',
#         'diff',
#         'diff2'],
#        'feature_set': 'full'},
#       'prh.pitch': {'transforms': ['raw'], 'feature_set': 'full'},
#       'prh.roll': {'transforms': ['raw'], 'feature_set': 'full'},
#       'prh.heading': {'transforms': ['raw'],
#        'feature_set': 'full',
#        'required': False},
#       'velocity.velocity': {'transforms': ['raw'],
#        'feature_set': 'full',
#        'required': False},
#       'stroke_rate.stroke_rate': {'transforms': ['raw'],
#        'feature_set': 'medium',
#        'required': False}},
#      'primary_input_channel_for_ranking': 'depth.depth',
#      'corr_threshold': 0.8,
#      'n_clusters': 5,
#      'max_k': 8,
#      'run_pca': True,
#      'run_tsne': False,
#      'run_umap': True}},
#    'features': {'normalization_level': 'deployment',
#     'cluster_length_mode': 'variable',
#     'window_s': 30,
#     'stride_s': 10,
#     'min_samples_per_chunk': 5,
#     'max_chunks_per_deployment': 50000,
#     'max_chunks_total': 1200000,
#     'test_run': False,
#     'test_max_chunks_per_deployment': 1000,
#     'umap_sample_frac': 0.1,
#     'random_state': 42,
#     'strict_qc': False,
#     'sampling_compatibility_tolerance': 0.05,
#     'channel_feature_spec': {'depth.depth': {'transforms': ['raw',
#        'diff',
#        'diff2'],
#       'feature_set': 'full'},
#      'stroke_rate.stroke_rate': {'transforms': ['raw'],
#       'feature_set': 'medium',
#       'required': False},
#      'prh.pitch': {'transforms': ['raw'],
#       'feature_set': 'full',
#       'required': False},
#      'prh.roll': {'transforms': ['raw'],
#       'feature_set': 'full',
#       'required': False},
#      'prh.heading': {'transforms': ['raw'],
#       'feature_set': 'full',
#       'required': False},
#      'heart_rate.heart_rate': {'transforms': ['raw'],
#       'feature_set': 'medium',
#       'required': False},
#      'heart_rate_analysis.heart_rate_vlf_power': {'transforms': ['raw'],
#       'feature_set': 'medium',
#       'required': False},
#      'is_sleepspiral.is_sleepspiral': {'transforms': ['raw'],
#       'feature_set': 'minimal',
#       'required': False},
#      'eeg_analysis.eeg_f3_delta_power': {'transforms': ['raw'],
#       'feature_set': 'medium',
#       'required': False}},
#     'preprocessing': {'standardized_channels': {'depth.depth': {'method': 'adaptive_gaussian_quantized',
#        'quantize_step': 1.0,
#        'base_smooth_seconds': 6,
#        'coarse_smooth_seconds': 12,
#        'coarse_interval_threshold_s': 5,
#        'coarse_resolution_threshold': 1.0,
#        'derivative_orders': [0, 1, 2],
#        'output_prefix': 'standardized_depth'}}}},
#    'unsupervised': {'clustering_window_scope': 'all_windows',
#     'cluster_passes': [{'name': 'k2',
#       'n_clusters': 2,
#       'channel_feature_spec': {'depth.depth': {'transforms': ['raw'],
#         'feature_set': 'full'}}},
#      {'name': 'k5',
#       'n_clusters': 5,
#       'channel_feature_spec': {'depth.depth': {'transforms': ['diff', 'diff2'],
#         'feature_set': 'full'}}}],
#     'primary_input_channel_for_ranking': 'depth.depth',
#     'corr_threshold': 0.8,
#     'n_clusters': 'auto',
#     'max_k': 8,
#     'run_pca': True,
#     'run_tsne': False,
#     'run_umap': False},
#    'supervised': {'enabled': True,
#     'config': {'test_size': 0.3,
#      'stratify_split_by_dataset_label': True,
#      'rf_n_estimators': 500,
#      'rf_min_samples_leaf': 2,
#      'rf_class_weight': 'balanced_subsample',
#      'enable_lightgbm': False,
#      'enable_svm': False,
#      'enable_knn': False,
#      'enable_channel_ablation': True,
#      'ablation_mode': 'grouped_forward_addition',
#      'ablation_feature_groups': [{'label': 'TDR Only',
#        'channels': ['depth.depth']},
#       {'label': 'TDR + SR',
#        'channels': ['depth.depth', 'stroke_rate.stroke_rate']},
#       {'label': 'TDR + SR + PR',
#        'channels': ['depth.depth',
#         'stroke_rate.stroke_rate',
#         'prh.pitch',
#         'prh.roll']},
#       {'label': 'TDR + SR + PR + H',
#        'channels': ['depth.depth',
#         'stroke_rate.stroke_rate',
#         'prh.pitch',
#         'prh.roll',
#         'prh.heading']},
#       {'label': 'TDR + SR + PR + H + V',
#        'channels': ['depth.depth',
#         'stroke_rate.stroke_rate',
#         'prh.pitch',
#         'prh.roll',
#         'prh.heading',
#         'velocity.velocity']}],
#      'include_algorithmic_baseline': True,
#      'prediction_scope': 'all_windows',
#      'confidence_threshold': 0.4,
#      'use_probability_calibration': True,
#      'calibration_method': 'sigmoid',
#      'calibration_cv': 3,
#      'source_dataset_ids': ['mian-juv-nese_sleep_lml-ano_JKB'],
#      'source_training_deployment_ids_always': [],
#      'source_holdout_folds': [{'id': 'nese_fold_2021-04-04',
#        'holdout_deployment_ids': ['2021-04-04_mian-009'],
#        'additional_train_deployment_ids': ['2021-04-17_mian-011',
#         '2022-04-01_mian-013']},
#       {'id': 'nese_fold_2021-04-17',
#        'holdout_deployment_ids': ['2021-04-17_mian-011'],
#        'additional_train_deployment_ids': ['2021-04-04_mian-009',
#         '2022-04-01_mian-013']},
#       {'id': 'nese_fold_2022-04-01',
#        'holdout_deployment_ids': ['2022-04-01_mian-013'],
#        'additional_train_deployment_ids': ['2021-04-04_mian-009',
#         '2021-04-17_mian-011']}],
#      'transfer_normalization': 'per_deployment_zscore',
#      'transfer_target_scope': 'all_non_source',
#      'transfer_source_split_mode': 'random_70_30',
#      'transfer_fusion_modes': ['none', 'algorithmic_gate'],
#      'export_rf_events': True,
#      'context_filters': ['inferred_buoyancy_must-be-aligned',
#       'gliding_must-be-true'],
#      'label_group': 'WAKE_v_SLEEP_SEALS'}},
#    'summary': {'plots': {'interactive_review': {'enabled': True,
#       'deployment_scope': 'first_per_dataset',
#       'time_range_mode': 'full_deployment'}},
#     'window_trim': {'enabled': False,
#      'source_channel': 'depth.depth',
#      'rule': 'first_last_depth_threshold',
#      'depth_threshold_m': 10.0}}},
#   'mian_sleep_state_rf_test': {'scope': {'analysis_id': 'mian_sleep_state_rf_test',
#     'dataset_ids': ['mian-juv-nese_sleep_lml-ano_JKB'],
#     'deployment_ids': ['2021-04-04_mian-009',
#      '2021-04-17_mian-011',
#      '2022-04-01_mian-013'],
#     'expected_signals': ['depth',
#      'prh',
#      'stroke_rate',
#      'heart_rate',
#      'heart_rate_analysis',
#      'eeg_analysis']},
#    'features': {'normalization_level': 'deployment',
#     'cluster_length_mode': 'variable',
#     'window_s': 30,
#     'stride_s': 10,
#     'min_samples_per_chunk': 5,
#     'max_chunks_per_deployment': 40000,
#     'max_chunks_total': 1000000,
#     'test_run': False,
#     'test_max_chunks_per_deployment': 1000,
#     'umap_sample_frac': 0.1,
#     'random_state': 42,
#     'strict_qc': False,
#     'sampling_compatibility_tolerance': 0.05,
#     'channel_feature_spec': {'depth.depth': {'transforms': ['raw',
#        'diff',
#        'diff2'],
#       'feature_set': 'full'},
#      'stroke_rate.stroke_rate': {'transforms': ['raw'],
#       'feature_set': 'medium',
#       'required': False},
#      'prh.pitch': {'transforms': ['raw'],
#       'feature_set': 'full',
#       'required': False},
#      'prh.roll': {'transforms': ['raw'],
#       'feature_set': 'full',
#       'required': False},
#      'prh.heading': {'transforms': ['raw'],
#       'feature_set': 'full',
#       'required': False},
#      'heart_rate.heart_rate': {'transforms': ['raw'],
#       'feature_set': 'medium',
#       'required': False},
#      'heart_rate_analysis.heart_rate_vlf_power': {'transforms': ['raw'],
#       'feature_set': 'medium',
#       'required': False},
#      'is_sleepspiral.is_sleepspiral': {'transforms': ['raw'],
#       'feature_set': 'minimal',
#       'required': False},
#      'eeg_analysis.eeg_f3_delta_power': {'transforms': ['raw'],
#       'feature_set': 'medium',
#       'required': False}},
#     'preprocessing': {'standardized_channels': {'depth.depth': {'method': 'adaptive_gaussian_quantized',
#        'quantize_step': 1.0,
#        'base_smooth_seconds': 6,
#        'coarse_smooth_seconds': 12,
#        'coarse_interval_threshold_s': 5,
#        'coarse_resolution_threshold': 1.0,
#        'derivative_orders': [0, 1, 2],
#        'output_prefix': 'standardized_depth'}}}},
#    'unsupervised': {'clustering_window_scope': 'all_windows',
#     'cluster_passes': [{'name': 'k2',
#       'n_clusters': 2,
#       'channel_feature_spec': {'depth.depth': {'transforms': ['raw'],
#         'feature_set': 'full'}}},
#      {'name': 'k5',
#       'n_clusters': 5,
#       'channel_feature_spec': {'depth.depth': {'transforms': ['diff', 'diff2'],
#         'feature_set': 'full'}}}],
#     'primary_input_channel_for_ranking': 'depth.depth',
#     'corr_threshold': 0.8,
#     'n_clusters': 'auto',
#     'max_k': 8,
#     'run_pca': True,
#     'run_tsne': False,
#     'run_umap': False},
#    'supervised': {'enabled': True,
#     'config': {'prediction_scope': 'labeled_windows_only',
#      'source_dataset_ids': ['mian-juv-nese_sleep_lml-ano_JKB'],
#      'source_training_deployment_ids_always': [],
#      'source_holdout_folds': [{'id': 'jkb_holdout_2021-04-04_mian-009',
#        'holdout_deployment_ids': ['2021-04-04_mian-009'],
#        'additional_train_deployment_ids': ['2021-04-17_mian-011',
#         '2022-04-01_mian-013']},
#       {'id': 'jkb_holdout_2021-04-17_mian-011',
#        'holdout_deployment_ids': ['2021-04-17_mian-011'],
#        'additional_train_deployment_ids': ['2021-04-04_mian-009',
#         '2022-04-01_mian-013']},
#       {'id': 'jkb_holdout_2022-04-01_mian-013',
#        'holdout_deployment_ids': ['2022-04-01_mian-013'],
#        'additional_train_deployment_ids': ['2021-04-04_mian-009',
#         '2021-04-17_mian-011']}],
#      'test_size': 0.3,
#      'transfer_target_scope': 'all_non_source',
#      'transfer_normalization': 'per_deployment_zscore',
#      'transfer_fusion_modes': ['none'],
#      'rf_n_estimators': 500,
#      'rf_min_samples_leaf': 2,
#      'rf_class_weight': 'balanced_subsample',
#      'enable_lightgbm': False,
#      'enable_svm': False,
#      'enable_knn': False,
#      'enable_channel_ablation': True,
#      'ablation_mode': 'grouped_forward_addition',
#      'ablation_feature_groups': [{'label': 'TDR Only',
#        'channels': ['depth.depth']},
#       {'label': 'TDR + SR',
#        'channels': ['depth.depth', 'stroke_rate.stroke_rate']},
#       {'label': 'TDR + SR + PR',
#        'channels': ['depth.depth',
#         'stroke_rate.stroke_rate',
#         'prh.pitch',
#         'prh.roll']},
#       {'label': 'TDR + SR + PRH',
#        'channels': ['depth.depth',
#         'stroke_rate.stroke_rate',
#         'prh.pitch',
#         'prh.roll',
#         'prh.heading',
#         'is_sleepspiral.is_sleepspiral']},
#       {'label': 'TDR + SR + PRH + HR',
#        'channels': ['depth.depth',
#         'stroke_rate.stroke_rate',
#         'prh.pitch',
#         'prh.roll',
#         'prh.heading',
#         'is_sleepspiral.is_sleepspiral',
#         'heart_rate.heart_rate']},
#       {'label': 'TDR + SR + PRH + HR + HRV',
#        'channels': ['depth.depth',
#         'stroke_rate.stroke_rate',
#         'prh.pitch',
#         'prh.roll',
#         'prh.heading',
#         'is_sleepspiral.is_sleepspiral',
#         'heart_rate.heart_rate',
#         'heart_rate_analysis.heart_rate_vlf_power']},
#       {'label': 'TDR + SR + PRH + HR + HRV + EEG_DELTA',
#        'channels': ['depth.depth',
#         'stroke_rate.stroke_rate',
#         'prh.pitch',
#         'prh.roll',
#         'prh.heading',
#         'heart_rate.heart_rate',
#         'is_sleepspiral.is_sleepspiral',
#         'heart_rate_analysis.heart_rate_vlf_power',
#         'eeg_analysis.eeg_f3_delta_power']}],
#      'include_algorithmic_baseline': False,
#      'confidence_threshold': 0.4,
#      'use_probability_calibration': True,
#      'calibration_method': 'sigmoid',
#      'calibration_cv': 3,
#      'export_rf_events': False,
#      'label_group': 'SWS_v_REM_SEALS'}},
#    'summary': {'plots': {'interactive_review': {'enabled': True,
#       'deployment_scope': 'first_per_dataset',
#       'time_range_mode': 'full_deployment'}},
#     'window_trim': {'enabled': False,
#      'source_channel': 'depth.depth',
#      'rule': 'first_last_depth_threshold',
#      'depth_threshold_m': 10.0}}},
#   'cafa_silky_motion_only': {'scope': {'analysis_id': 'cafa_silky_motion_only',
#     'dataset_ids': ['cafa-adult_tdr-imu_BT'],
#     'deployment_ids': ['2021-08-03_cafa-001'],
#     'expected_signals': ['activity', 'accelerometer']},
#    'features': {'normalization_level': 'deployment',
#     'cluster_length_mode': 'fixed',
#     'duration_s': 300,
#     'min_samples_per_chunk': 40,
#     'max_chunks_per_deployment': 200000,
#     'max_chunks_total': 200000,
#     'test_run': False,
#     'umap_sample_frac': 0.2,
#     'random_state': 42,
#     'strict_qc': False,
#     'channel_feature_spec': {'activity.activity': {'transforms': ['raw'],
#       'feature_set': 'medium'},
#      'accelerometer.ax': {'transforms': ['raw'], 'feature_set': 'medium'},
#      'accelerometer.ay': {'transforms': ['raw'], 'feature_set': 'medium'},
#      'accelerometer.az': {'transforms': ['raw'], 'feature_set': 'medium'}}},
#    'unsupervised': {'cluster_passes': [{'name': 'k3',
#       'n_clusters': 3,
#       'channel_feature_spec': {'activity.activity': {'transforms': ['raw'],
#         'feature_set': 'medium'},
#        'accelerometer.ax': {'transforms': ['raw'], 'feature_set': 'medium'},
#        'accelerometer.ay': {'transforms': ['raw'], 'feature_set': 'medium'},
#        'accelerometer.az': {'transforms': ['raw'], 'feature_set': 'medium'}}},
#      {'name': 'k5',
#       'n_clusters': 5,
#       'channel_feature_spec': {'activity.activity': {'transforms': ['raw'],
#         'feature_set': 'medium'},
#        'accelerometer.ax': {'transforms': ['raw'], 'feature_set': 'medium'},
#        'accelerometer.ay': {'transforms': ['raw'], 'feature_set': 'medium'},
#        'accelerometer.az': {'transforms': ['raw'], 'feature_set': 'medium'}}}],
#     'primary_input_channel_for_ranking': 'activity.activity',
#     'corr_threshold': 0.8,
#     'n_clusters': 'auto',
#     'max_k': 8,
#     'run_pca': True,
#     'run_tsne': False,
#     'run_umap': False},
#    'supervised': {'enabled': False},
#    'summary': {'config': {'primary_method_kind': 'clustering',
#      'primary_method_id': 'clustered_windows',
#      'budget_label_mode': 'canonical',
#      'actograms': {'daily': False, 'continuous': False}}}},
#   'cafa_silky_all_channels': {'scope': {'analysis_id': 'cafa_silky_all_channels',
#     'dataset_ids': ['cafa-adult_tdr-imu_BT'],
#     'deployment_ids': ['2021-08-03_cafa-001'],
#     'expected_signals': ['activity',
#      'accelerometer',
#      'depth',
#      'temperature_ext']},
#    'features': {'normalization_level': 'deployment',
#     'cluster_length_mode': 'fixed',
#     'duration_s': 300,
#     'min_samples_per_chunk': 40,
#     'max_chunks_per_deployment': 200000,
#     'max_chunks_total': 200000,
#     'test_run': False,
#     'umap_sample_frac': 0.2,
#     'random_state': 42,
# ...
#     'keep_if': {'comparator': '>=', 'threshold': 200.0}},
#    'action_on_fail': 'reject',
#    'reject_reason': 'postpositive_negative_too_short'},
#   'early_trip_refinement': {'enabled': True,
#    'target_state_keys': ['find_rest.long_drift'],
#    'applies_when': {'inferred_trip_phase_in': ['pre_positive',
#      'never_positive'],
#     'elapsed_days': {'comparator': '<', 'threshold': 15.0}},
#    'rule': {'mode': 'threshold_gate',
#     'value_expr': 'abs(drift_rate_ms - inferred_buoyancy_early_reference_value)',
#     'keep_if': {'comparator': '<', 'threshold': 0.15}},
#    'on_missing_covariate': 'skip_filter',
#    'action_on_fail': 'reject',
#    'reject_reason': 'early_trip_refinement_failed'},
#   'late_trip_refinement': {'enabled': True,
#    'target_state_keys': ['find_rest.long_drift'],
#    'applies_when': {'inferred_trip_phase_in': ['never_positive']},
#    'rule': {'mode': 'threshold_gate',
#     'value_expr': 'abs(drift_rate_ms - inferred_buoyancy_late_reference_value)',
#     'keep_if': {'comparator': '<', 'threshold': 0.15}},
#    'on_missing_covariate': 'skip_filter',
#    'action_on_fail': 'reject',
#    'reject_reason': 'late_trip_refinement_failed'}},
#  'supervised_context_filter_definitions': {'inferred_buoyancy_must-be-aligned': {'enabled': True,
#    'applies_when': {'predicted_label_pre_context': '__positive_label__'},
#    'rule': {'mode': 'threshold_gate',
#     'field': 'algorithmic_context_keep',
#     'keep_if': {'comparator': '==', 'threshold': 1}},
#    'on_missing_covariate': 'reject',
#    'action_on_fail': 'reject',
#    'reject_reason': 'rf_sleep_context_rejected'},
#   'gliding_must-be-true': {'enabled': True,
#    'applies_when': {'predicted_label_pre_context': '__positive_label__'},
#    'rule': {'mode': 'threshold_gate',
#     'field': 'algorithmic_segment_mean_stroke_rate_spm',
#     'keep_if': {'comparator': '<', 'threshold': 10.0}},
#    'on_missing_covariate': 'reject',
#    'action_on_fail': 'reject',
#    'reject_reason': 'rf_sleep_not_gliding'}},
#  'supervised_label_group_definitions': {'BEHAVIOR_LIONS': {'label_groups': {'Active': ['behavior_active_galumphing',
#      'behavior_active_walking',
#      'behavior_active_trotting',
#      'behavior_active_running',
#      'behavior_active_swimming',
#      'behavior_active_unspecified',
#      'active_galumphing',
#      'active_walking',
#      'active_trotting',
#      'active_running',
#      'active_swimming',
#      'active_unspecified'],
#     'Feeding': ['behavior_calm_feeding', 'calm_feeding'],
#     'Drinking': ['behavior_calm_drinking', 'calm_drinking'],
#     'Vigilant': ['behavior_calm_scanning', 'calm_scanning', 'calm_watching'],
#     'Resting': ['behavior_motionless_resting',
#      'motionless_resting',
#      'behavior_calm_resting',
#      'calm_resting',
#      'motionless_sleeping'],
#     'Calm': ['behavior_calm_vocalizing',
#      'behavior_calm_grooming',
#      'behavior_calm_repositioning',
#      'behavior_calm_yawning',
#      'behavior_calm_other',
#      'behavior_calm_unspecified',
#      'calm_vocalizing',
#      'calm_grooming',
#      'calm_repositioning',
#      'calm_yawning',
#      'calm_other',
#      'calm_unspecified']},
#    'label_prefixes': ['behavior_active_',
#     'behavior_calm_',
#     'behavior_motionless_'],
#    'label_event_keys': [],
#    'drop_labels': [],
#    'event_keys': {'Active': 'behavior_active_unspecified',
#     'Feeding': 'behavior_calm_feeding',
#     'Drinking': 'behavior_calm_drinking',
#     'Vigilant': 'behavior_calm_scanning',
#     'Resting': 'behavior_motionless_resting',
#     'Calm': 'behavior_calm_unspecified',
#     '__uncertain__': 'behavior_calm_other',
#     'Unknown': 'behavior_calm_other',
#     'Other Motion': 'behavior_calm_other'}},
#   'WAKE_v_SLEEP_SEALS': {'algorithmic_terminals': {'calm_uw_gliding': {'event_key': 'behavior_calm_gliding_diving',
#      'label_name': 'gliding_uw',
#      'pretty_label': 'Gliding (UW)',
#      'label_code': 5},
#     'active_uw_swimming': {'event_key': 'behavior_active_swimming_diving',
#      'label_name': 'swimming_uw',
#      'pretty_label': 'Swimming (UW)',
#      'label_code': 0},
#     'resting_surface': {'event_key': 'behavior_motionless_resting_surface',
#      'label_name': 'resting_surface',
#      'pretty_label': 'Resting (Surface)',
#      'label_code': 1},
#     'resting_benthic': {'event_key': 'behavior_motionless_resting_benthic',
#      'label_name': 'resting_benthic',
#      'pretty_label': 'Resting (Benthic)',
#      'label_code': 2},
#     'long_drift': {'event_key': 'behavior_motionless_resting_drift',
#      'label_name': 'resting_drift',
#      'pretty_label': 'Resting (Drift)',
#      'label_code': 3},
#     'calm_surface_gliding': {'event_key': 'behavior_calm_gliding_surface',
#      'label_name': 'gliding_surface',
#      'pretty_label': 'Gliding (Surface)',
#      'label_code': 7},
#     'active_surface_swimming': {'event_key': 'behavior_active_swimming_surface',
#      'label_name': 'swimming_surface',
#      'pretty_label': 'Swimming (Surface)',
#      'label_code': 6},
#     'unscorable': {'event_key': 'behavior_unscorable',
#      'label_name': 'unscorable',
#      'pretty_label': 'Unscorable (unclear)',
#      'label_code': 4}},
#    'label_groups': {'WAKE': ['sleep-state_waking_active-quiet-drowsiness',
#      'sleep-state_waking_active-quiet',
#      'sleep-state_waking_active',
#      'sleep-state_waking_quiet',
#      'sleep-state_waking_drowsiness',
#      'active_quiet_drowsiness',
#      'active_quiet',
#      'active',
#      'quiet',
#      'drowsiness'],
#     'SLEEP': ['sleep-state_sleep_slow-wave-sleep',
#      'sleep-state_sleep_lowest-voltage-sws',
#      'sleep-state_sleep_low-voltage-sws',
#      'sleep-state_sleep_highest-voltage-sws',
#      'sleep-state_sleep_unihemispheric-sws',
#      'sleep-state_sleep_asymmetrical-sws',
#      'sleep-state_sleep_unihemispheric-sws-right',
#      'sleep-state_sleep_unihemispheric-sws-left',
#      'sleep-state_sleep_bilateral-sws',
#      'slow_wave_sleep',
#      'sws',
#      'lowest_voltage_sws',
#      'low_voltage_sws',
#      'highest_voltage_sws',
#      'unihemispheric_sws',
#      'asymmetrical_sws',
#      'unihemispheric_sws_right',
#      'unihemispheric_sws_left',
#      'bilateral_sws',
#      'sleep-state_sleep_certain-rem',
#      'sleep-state_sleep_putative-rem',
#      'sleep_state.certain_rem_sleep',
#      'sleep_state.putative_rem_sleep',
#      'certain_rem',
#      'certain_rem_sleep',
#      'putative_rem',
#      'putative_rem_sleep',
#      'rem_bilateral_sws',
#      'unspecified']},
#    'label_prefixes': ['sleep-state_', 'sleep_state.'],
#    'label_event_keys': [],
#    'drop_labels': ['sleep-state_unscorable_unclear',
#     'sleep_state.unscorable',
#     'sleep_state_unscorable',
#     'unclear',
#     'unscorable'],
#    'event_keys': {'WAKE': 'sleep-state_waking_active-quiet',
#     'SLEEP': 'sleep-state_sleep_slow-wave-sleep'}},
#   'WAKE_v_REST_SEALS': {'algorithmic_terminals': {'calm_uw_gliding': {'event_key': 'behavior_calm_gliding_diving',
#      'label_name': 'gliding_uw',
#      'pretty_label': 'Gliding (UW)',
#      'label_code': 5},
#     'active_uw_swimming': {'event_key': 'behavior_active_swimming_diving',
#      'label_name': 'swimming_uw',
#      'pretty_label': 'Swimming (UW)',
#      'label_code': 0},
#     'resting_surface': {'event_key': 'behavior_motionless_resting_surface',
#      'label_name': 'resting_surface',
#      'pretty_label': 'Resting (Surface)',
#      'label_code': 1},
#     'resting_benthic': {'event_key': 'behavior_motionless_resting_benthic',
#      'label_name': 'resting_benthic',
#      'pretty_label': 'Resting (Benthic)',
#      'label_code': 2},
#     'long_drift': {'event_key': 'behavior_motionless_resting_drift',
#      'label_name': 'resting_drift',
#      'pretty_label': 'Resting (Drift)',
#      'label_code': 3},
#     'calm_surface_gliding': {'event_key': 'behavior_calm_gliding_surface',
#      'label_name': 'gliding_surface',
#      'pretty_label': 'Gliding (Surface)',
#      'label_code': 7},
#     'active_surface_swimming': {'event_key': 'behavior_active_swimming_surface',
#      'label_name': 'swimming_surface',
#      'pretty_label': 'Swimming (Surface)',
#      'label_code': 6},
#     'unscorable': {'event_key': 'behavior_unscorable',
#      'label_name': 'unscorable',
#      'pretty_label': 'Unscorable (unclear)',
#      'label_code': 4}},
#    'label_groups': {'WAKE': ['sleep-state_waking_active-quiet-drowsiness',
#      'sleep-state_waking_active-quiet',
#      'sleep-state_waking_active',
#      'sleep-state_waking_quiet',
#      'sleep-state_waking_drowsiness',
#      'active_quiet_drowsiness',
#      'active_quiet',
#      'active',
#      'quiet',
#      'drowsiness'],
#     'REST': ['sleep-state_sleep_slow-wave-sleep',
#      'sleep-state_sleep_lowest-voltage-sws',
#      'sleep-state_sleep_low-voltage-sws',
#      'sleep-state_sleep_highest-voltage-sws',
#      'sleep-state_sleep_unihemispheric-sws',
#      'sleep-state_sleep_asymmetrical-sws',
#      'sleep-state_sleep_unihemispheric-sws-right',
#      'sleep-state_sleep_unihemispheric-sws-left',
#      'sleep-state_sleep_bilateral-sws',
#      'slow_wave_sleep',
#      'sws',
#      'lowest_voltage_sws',
#      'low_voltage_sws',
#      'highest_voltage_sws',
#      'unihemispheric_sws',
#      'asymmetrical_sws',
#      'unihemispheric_sws_right',
#      'unihemispheric_sws_left',
#      'bilateral_sws',
#      'sleep-state_sleep_certain-rem',
#      'sleep-state_sleep_putative-rem',
#      'sleep_state.certain_rem_sleep',
#      'sleep_state.putative_rem_sleep',
#      'certain_rem',
#      'certain_rem_sleep',
#      'putative_rem',
#      'putative_rem_sleep',
#      'rem_bilateral_sws',
#      'unspecified']},
#    'label_prefixes': ['sleep-state_', 'sleep_state.'],
#    'label_event_keys': [],
#    'drop_labels': ['sleep-state_unscorable_unclear',
#     'sleep_state.unscorable',
#     'sleep_state_unscorable',
#     'unclear',
#     'unscorable'],
#    'event_keys': {'WAKE': 'behavior_active_waking_unspecified',
#     'REST': 'behavior_motionless_resting_unspecified'}},
#   'SWS_v_REM_SEALS': {'algorithmic_terminals': {'calm_uw_gliding': {'event_key': 'behavior_calm_gliding_diving',
#      'label_name': 'gliding_uw',
#      'pretty_label': 'Gliding (UW)',
#      'label_code': 5},
#     'active_uw_swimming': {'event_key': 'behavior_active_swimming_diving',
#      'label_name': 'swimming_uw',
#      'pretty_label': 'Swimming (UW)',
#      'label_code': 0},
#     'resting_surface': {'event_key': 'behavior_motionless_resting_surface',
#      'label_name': 'resting_surface',
#      'pretty_label': 'Resting (Surface)',
#      'label_code': 1},
#     'resting_benthic': {'event_key': 'behavior_motionless_resting_benthic',
#      'label_name': 'resting_benthic',
#      'pretty_label': 'Resting (Benthic)',
#      'label_code': 2},
#     'long_drift': {'event_key': 'behavior_motionless_resting_drift',
#      'label_name': 'resting_drift',
#      'pretty_label': 'Resting (Drift)',
#      'label_code': 3},
#     'calm_surface_gliding': {'event_key': 'behavior_calm_gliding_surface',
#      'label_name': 'gliding_surface',
#      'pretty_label': 'Gliding (Surface)',
#      'label_code': 7},
#     'active_surface_swimming': {'event_key': 'behavior_active_swimming_surface',
#      'label_name': 'swimming_surface',
#      'pretty_label': 'Swimming (Surface)',
#      'label_code': 6},
#     'unscorable': {'event_key': 'behavior_unscorable',
#      'label_name': 'unscorable',
#      'pretty_label': 'Unscorable (unclear)',
#      'label_code': 4}},
#    'label_groups': {'SWS': ['sleep-state_sleep_slow-wave-sleep',
#      'sleep-state_sleep_lowest-voltage-sws',
#      'sleep-state_sleep_low-voltage-sws',
#      'sleep-state_sleep_highest-voltage-sws',
#      'sleep-state_sleep_unihemispheric-sws',
#      'sleep-state_sleep_asymmetrical-sws',
#      'sleep-state_sleep_unihemispheric-sws-right',
#      'sleep-state_sleep_unihemispheric-sws-left',
#      'sleep-state_sleep_bilateral-sws',
#      'slow_wave_sleep',
#      'sws',
#      'lowest_voltage_sws',
#      'low_voltage_sws',
#      'highest_voltage_sws',
#      'unihemispheric_sws',
#      'asymmetrical_sws',
#      'unihemispheric_sws_right',
#      'unihemispheric_sws_left',
#      'bilateral_sws'],
#     'REM': ['sleep-state_sleep_certain-rem',
#      'sleep-state_sleep_putative-rem',
#      'certain_rem',
#      'certain_rem_sleep',
#      'putative_rem',
#      'putative_rem_sleep']},
#    'label_prefixes': ['sleep-state_', 'sleep_state.'],
#    'label_event_keys': [],
#    'drop_labels': ['sleep-state_unscorable_unclear',
#     'sleep_state.unscorable',
#     'sleep_state_unscorable',
#     'unclear',
#     'unscorable'],
#    'event_keys': {'SWS': 'sleep-state_sleep_putative-sws',
#     'REM': 'sleep-state_sleep_putative-rem'}}},
#  'segmentation_event_definitions': {'base': {'algorithmic_segments': {'defaults': {'type': 'state',
#      'short_description': '{label_name}',
#      'long_description': 'Algorithmic segmentation ({variant_id}) [{segment_stage}]'},
#     'input_labels': ['active_uw_swimming',
#      'calm_uw_gliding',
#      'resting_surface',
#      'resting_benthic',
#      'long_drift',
#      'active_surface_swimming',
#      'calm_surface_gliding',
#      'unscorable'],
#     'output_labels': ['behavior_active_swimming_diving',
#      'behavior_calm_gliding_diving',
#      'behavior_motionless_resting_surface',
#      'behavior_motionless_resting_benthic',
#      'behavior_motionless_resting_drift',
#      'behavior_active_swimming_surface',
#      'behavior_calm_gliding_surface',
#      'behavior_unscorable'],
#     'event_keys': {'find_rest.initial': {'short_description': 'find_rest.initial',
#       'long_description': 'Initial algorithmic segment candidate'},
#      'find_rest.filtered': {'short_description': 'find_rest.filtered',
#       'long_description': 'Context-filtered algorithmic segment'},
#      'rest.initial': {'short_description': 'rest.initial',
#       'long_description': 'Initial algorithmic segment candidate'},
#      'rest.filtered': {'short_description': 'rest.filtered',
#       'long_description': 'Context-filtered algorithmic segment'},
#      'behavior_motionless_resting_surface': {'short_description': 'behavior_motionless_resting_surface',
#       'long_description': 'Algorithmic surface motionless resting segment'},
#      'behavior_motionless_resting_benthic': {'short_description': 'behavior_motionless_resting_benthic',
#       'long_description': 'Algorithmic benthic motionless resting segment'},
#      'behavior_motionless_resting_drift': {'short_description': 'behavior_motionless_resting_drift',
#       'long_description': 'Algorithmic drift motionless resting segment'},
#      'behavior_active_swimming_diving': {'short_description': 'Swimming (UW)',
#       'long_description': 'Algorithmic underwater active swimming segment (stroke_rate above threshold)'},
#      'behavior_calm_gliding_diving': {'short_description': 'Gliding (UW)',
#       'long_description': 'Algorithmic underwater calm gliding segment (stroke_rate below threshold, non-rest)'},
#      'behavior_active_swimming_surface': {'short_description': 'Swimming (Surface)',
#       'long_description': 'Algorithmic surface active swimming segment (stroke_rate above threshold)'},
#      'behavior_calm_gliding_surface': {'short_description': 'Gliding (Surface)',
#       'long_description': 'Algorithmic surface calm gliding segment (stroke_rate below threshold, non-rest)'},
#      'behavior_unscorable': {'short_description': 'Unscorable (unclear)',
#       'long_description': 'Algorithmic segment excluded as unscorable'}},
#     'variants': {'find_rest': {'defaults': {'long_description': 'Algorithmic segmentation (find_rest) [{segment_stage}]'}},
#      'rest': {'defaults': {'long_description': 'Algorithmic segmentation (rest) [{segment_stage}]'}}}},
#    'supervised_predictions': {'defaults': {'type': 'state',
#      'short_description': 'supervised_{label_name_normalized}_start',
#      'long_description': 'Supervised prediction state: {label_name}'},
#     'input_labels': ['source: supervised.label_group'],
#     'output_labels': ['target: supervised.event_keys'],
#     'event_keys': {'rf_unknown': {'short_description': 'supervised_unknown_start',
#       'long_description': 'Supervised prediction state: Unknown/uncertain'}},
#     'labels': {'Unknown': {'short_description': 'supervised_unknown_start',
#       'long_description': 'Supervised prediction state: Unknown/uncertain'}}}}}}

# %%
# --- Prepare storage ---
all_event_data = []
all_signal_data = defaultdict(list)
metadata = {
    'deployment_ids': [],
    'signal_info': {},
    'logger_info': {},
    'animal_info': {},
    'deployment_info': {},
}

# --- Process deployments ---
for deployment_path in deployment_paths:
    deployment_id = deployment_path.name
    pkl_path = deployment_path / 'outputs' / 'data.pkl'

    with open(pkl_path, 'rb') as f:
        data_pkl = pickle.load(f)

    print(f"→ Processing {deployment_id}")
    metadata['deployment_ids'].append(deployment_id)

    # Event data
    if hasattr(data_pkl, 'event_data') and data_pkl.event_data is not None:
        df = data_pkl.event_data.copy()
        df['deployment_id'] = deployment_id
        all_event_data.append(df)

    # Signal data
    for signal, df in data_pkl.signal_data.items():
        df_copy = df.copy()
        df_copy['deployment_id'] = deployment_id
        all_signal_data[signal].append(df_copy)

    # Metadata
    metadata['signal_info'][deployment_id] = data_pkl.signal_info
    metadata['derived_info'][deployment_id] = data_pkl.derived_info
    metadata['logger_info'][deployment_id] = data_pkl.logger_info
    metadata['animal_info'][deployment_id] = data_pkl.animal_info
    metadata['deployment_info'][deployment_id] = data_pkl.deployment_info

# --- Build MEGA PICKLE ---
megadata_pkl = {
    'event_data': pd.concat(all_event_data, ignore_index=True) if all_event_data else None,
    'signal_data': {k: pd.concat(v, ignore_index=True) for k, v in all_signal_data.items()},
    'metadata': metadata
}

# --- Save output ---
output_path = os.path.join(dataset_folder, 'megadata_pkl.pkl')
with open(output_path, 'wb') as f:
    pickle.dump(megadata_pkl, f)

print(f"✅ MEGA PICKLE saved: {output_path}")

# %%
megadata_pkl['event_data']

# %%
megadata_pkl['signal_data']['prh']

# %%
from pyologger.process_data.sampling import calculate_sampling_frequency
import pandas as pd

def truncate_to_seconds(dt_series):
    return dt_series.dt.floor('s')

def downsample_and_merge_signal_data(megadata_pkl, keys, target_freq=1):
    derived = megadata_pkl['signal_data']
    dfs = {}

    # Step 1: Drop NA and collect sampling frequencies
    sampling_frequencies = {}

    for key in keys:
        df = derived[key].dropna().copy()
        unique_deployments = df['deployment_id'].unique()

        freqs = []
        for deployment_id in unique_deployments:
            sub = df[df['deployment_id'] == deployment_id]
            fs = calculate_sampling_frequency(sub['datetime'])
            freqs.append(fs)

        if len(set(freqs)) != 1:
            print(f"❌ Inconsistent sampling frequency in '{key}':")
            for i, deployment_id in enumerate(unique_deployments):
                print(f"   {deployment_id}: {freqs[i]:.2f} Hz")
            return None

        fs = freqs[0]
        print(f"✅ '{key}' has consistent sampling frequency: {fs:.2f} Hz")
        sampling_frequencies[key] = fs
        dfs[key] = df

    # Step 2: Downsample and truncate datetime
    downsampled = {}
    for key, df in dfs.items():
        step = int(sampling_frequencies[key] // target_freq)
        df = df.iloc[::step].reset_index(drop=True)
        df['datetime'] = truncate_to_seconds(df['datetime'])
        downsampled[key] = df

    # Step 3: Merge on 'datetime'
    merged_df = None
    for i, (key, df) in enumerate(downsampled.items()):
        if merged_df is None:
            merged_df = df
        else:
            merged_df = pd.merge(merged_df, df, on='datetime', how='inner', suffixes=('', f'_{key}'))

    # Step 4: Check deployment_id consistency row-wise
    deployment_cols = [col for col in merged_df.columns if col.startswith('deployment_id')]
    inconsistent_rows = merged_df[deployment_cols].nunique(axis=1) > 1
    if inconsistent_rows.any():
        print("❌ Inconsistent deployment IDs found in merged rows:")
        print(merged_df.loc[inconsistent_rows, ['datetime'] + deployment_cols])
        return None

    # Step 5: Collapse to one consistent deployment_id column (but keep it)
    merged_df['deployment_id'] = merged_df[deployment_cols[0]]
    # Optionally: Keep original columns or drop them
    # merged_df = merged_df.drop(columns=deployment_cols[1:])  # keep just one, drop others

    # Save result
    result_key = f"merged_{'_'.join(keys)}"
    megadata_pkl['signal_data'][result_key] = merged_df
    print(f"✅ Merged DataFrame saved as megadata_pkl['signal_data']['{result_key}']")
    return merged_df

# %%
merged_df = downsample_and_merge_signal_data(
    megadata_pkl,
    keys=['heart_rate', 'stroke_rate', 'prh', 'depth'],
    target_freq=1  # Hz
)
merged_df

merged_df['roll'] = abs(merged_df['roll'])

# %%
import plotly.express as px
import plotly.graph_objects as go

# Make sure the category dtype is correct
merged_df['deployment_id'] = merged_df['deployment_id'].astype('category')

# Original scatter plot with proper categorical coloring
fig = px.scatter(
    merged_df,
    x='stroke_rate',
    y='heart_rate',
    color='deployment_id',
    color_discrete_sequence=px.colors.qualitative.Set2,  # optional, helps make sure colors are distinct
    title='Heart Rate vs Stroke Rate',
    labels={'stroke_rate': 'depth (m)', 'heart_rate': 'Heart Rate (bpm)', 'deployment_id': 'Deployment ID'},
    opacity=0.3
)

fig.update_traces(marker=dict(size=5))
fig.update_layout(
    xaxis_title='depth (m)',
    yaxis_title='Heart Rate (bpm)',
    template='plotly_white'
)

# Add a single regression line (not per deployment)
trend_fig = px.scatter(
    merged_df,
    x='stroke_rate',
    y='heart_rate',
    trendline='ols'
)

# Extract just the trendline (usually the 1st or 2nd trace depending on how many groups)
trendline_trace = [trace for trace in trend_fig.data if trace.mode == 'lines'][0]

# Add the regression line to your original colorful scatter plot
fig.add_trace(trendline_trace)

fig.show()

# %%
import plotly.express as px
import plotly.graph_objects as go

# Make sure the category dtype is correct
merged_df['deployment_id'] = merged_df['deployment_id'].astype('category')

# Original scatter plot with proper categorical coloring
fig = px.scatter(
    merged_df,
    x='depth',
    y='heart_rate',
    color='deployment_id',
    color_discrete_sequence=px.colors.qualitative.Set2,  # optional, helps make sure colors are distinct
    title='Heart Rate vs Depth',
    labels={'depth': 'depth (m)', 'heart_rate': 'Heart Rate (bpm)', 'deployment_id': 'Deployment ID'},
    opacity=0.3
)

fig.update_traces(marker=dict(size=5))
fig.update_layout(
    xaxis_title='depth (m)',
    yaxis_title='Heart Rate (bpm)',
    template='plotly_white'
)

# Add a single regression line (not per deployment)
trend_fig = px.scatter(
    merged_df,
    x='depth',
    y='heart_rate',
    trendline='ols'
)

# Extract just the trendline (usually the 1st or 2nd trace depending on how many groups)
trendline_trace = [trace for trace in trend_fig.data if trace.mode == 'lines'][0]

# Add the regression line to your original colorful scatter plot
fig.add_trace(trendline_trace)

fig.show()

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import plotly.express as px

def plot_pca_plotly(
    merged_df,
    variables=None,
    color_by='deployment_id',  # can be continuous (e.g., heart_rate) or categorical
    n_components=2,
    opacity=0.7
):
    if variables is None:
        variables = ['heart_rate', 'stroke_rate', 'pitch', 'roll', 'heading', 'depth']

    # Ensure all required columns are present
    cols_needed = list(set(variables + [color_by, 'datetime']))
    data = merged_df[cols_needed].dropna().copy()

    # Standardize input variables
    X = data[variables].values
    X_scaled = StandardScaler().fit_transform(X)

    # Apply PCA
    pca = PCA(n_components=n_components)
    components = pca.fit_transform(X_scaled)
    explained_var = pca.explained_variance_ratio_

    # Build DataFrame for Plotly
    pca_df = pd.DataFrame(components, columns=[f'PC{i+1}' for i in range(n_components)])
    pca_df['datetime'] = data['datetime'].values
    pca_df[color_by] = data[color_by].values

    # Include original variables for hover tooltips
    for var in variables:
        pca_df[var] = data[var].values

    # Choose color scale depending on type
    color_args = {'color': color_by}
    if pd.api.types.is_numeric_dtype(data[color_by]):
        color_args['color_continuous_scale'] = 'Viridis'
    else:
        color_args['color_discrete_sequence'] = px.colors.qualitative.Set2

    # Plot
    fig = px.scatter(
        pca_df,
        x='PC1', y='PC2',
        title=f'PCA of Biologging Data colored by {color_by}',
        labels={
            'PC1': f'PC1 ({explained_var[0]*100:.1f}% variance)',
            'PC2': f'PC2 ({explained_var[1]*100:.1f}% variance)',
            color_by: color_by
        },
        hover_data=['datetime'] + variables + [color_by],
        opacity=opacity,
        **color_args
    )

    fig.update_layout(template='plotly_white')
    fig.show()

    return pca_df, pca

# %%
plot_pca_plotly(
    megadata_pkl['signal_data']['merged_heart_rate_stroke_rate_prh_depth'],
    color_by='heart_rate'
)

# %%
plot_pca_plotly(
    megadata_pkl['signal_data']['merged_heart_rate_stroke_rate_prh_depth'],
    color_by='stroke_rate'
)

# %%
plot_pca_plotly(
    megadata_pkl['signal_data']['merged_heart_rate_stroke_rate_prh_depth'],
    color_by='roll'
)

# %%
plot_pca_plotly(
    megadata_pkl['signal_data']['merged_heart_rate_stroke_rate_prh_depth'],
    color_by='depth'
)

# %%
# Import pyologger utilities
from pyologger.utils.folder_manager import *
from pyologger.plot_data.plotter import *

dataset_id = "oror-adult-orca_hr-sr-vid_sw_JKB-PP"
deployment_id = "2024-01-24_oror-001"

# Load important file paths and configurations
config, data_dir, color_mapping_path, montage_path = load_configuration()
# Streamlit load data
animal_id, dataset_id, deployment_id, dataset_folder, deployment_folder, data_pkl, param_manager = select_and_load_deployment(
    data_dir, dataset_id=dataset_id, deployment_id=deployment_id
    )
pkl_path = os.path.join(deployment_folder, 'outputs', 'data.pkl')

# %%
import xarray as xr

# Define the path to the NetCDF file
netcdf_path = os.path.join(deployment_folder, 'outputs', f'{deployment_id}_output.nc')

# Open the NetCDF file
data = xr.open_dataset(netcdf_path)

# Display the contents of the NetCDF file
display(data)
